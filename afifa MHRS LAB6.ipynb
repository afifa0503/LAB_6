# %% [markdown]
# NOISE REDUCTION

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread(r'D:\afifa (badin)\HH-ALPSRP187250480-H2.2_UA.tif', 0)  
image2 = cv2.imread(r'D:\afifa (badin)\HV-ALPSRP187250480-H2.2_UA.tif', 0)  

blurred_image = cv2.GaussianBlur(image, (5, 5), 0) 
blurred_image2 = cv2.GaussianBlur(image, (5, 5), 0)
plt.figure(figsize=(12, 4))
plt.subplot(141), plt.imshow(image, cmap='gray')
plt.title('Original Image 1'), plt.xticks([]), plt.yticks([])

plt.subplot(142), plt.imshow(blurred_image, cmap='gray')
plt.title('Denoised Image 1'), plt.xticks([]), plt.yticks([])

plt.subplot(143), plt.imshow(image2, cmap='gray')
plt.title('Original Image 2'), plt.xticks([]), plt.yticks([])

plt.subplot(144), plt.imshow(blurred_image2, cmap='gray')
plt.title('Denoised Image 2'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
cv2.imwrite('denoised_image.tif', blurred_image)
cv2.imwrite('denoised_image2.tif', blurred_image)
# Out:
# True

# %% [markdown]
# COLOR MAPPING

# %%
import numpy as np
image = cv2.imread(r'D:\afifa (badin)\HH-ALPSRP187250480-H2.2_UA.tif', 0)  
image2 = cv2.imread(r'D:\afifa (badin)\HV-ALPSRP187250480-H2.2_UA.tif', 0)  
blurred_image = cv2.GaussianBlur(image, (5, 5), 0) 
blurred_image2 = cv2.GaussianBlur(image, (5, 5), 0)

colormap_image = cv2.applyColorMap(blurred_image, cv2.COLORMAP_JET)
colormap_image2 = cv2.applyColorMap(blurred_image2, cv2.COLORMAP_JET)
plt.figure(figsize=(12, 4))
plt.subplot(121),plt.imshow(cv2.cvtColor(colormap_image, cv2.COLOR_BGR2RGB))
plt.title('Denoised Image_1 (Color-Mapped)')

plt.subplot(122),plt.imshow(cv2.cvtColor(colormap_image2, cv2.COLOR_BGR2RGB))
plt.title('Denoised Image_2 (Color-Mapped)')
plt.show()

# %% [markdown]
# MEAN SQUARED ERROR

# %%
def mse(image1, image2):
    return np.mean((image1 - image2) ** 2)

original_image1 =cv2.imread(r'D:\afifa (badin)\HH-ALPSRP187250480-H2.2_UA.tif', 0)  
denoised_image1 = cv2.GaussianBlur(original_image1, (5, 5), 0)
mse_value = mse(original_image1, denoised_image1)
print(f"Mean Squared Error of first image: {mse_value}")


original_image2 =cv2.imread(r'D:\afifa (badin)\HV-ALPSRP187250480-H2.2_UA.tif', 0)  
denoised_image2 = cv2.GaussianBlur(original_image2, (5, 5), 0)
mse_value2 = mse(original_image2, denoised_image2)
print(f"Mean Squared Error of second image: {mse_value2}")
# Out:
# Mean Squared Error of first image: 7.990846238601824
# Mean Squared Error of second image: 0.8515476063829788

# %% [markdown]
# STRUCTURAL SIMILARITY INDEX (SSIM)

# %%
pip install scikit-image
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: scikit-image in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (1.24.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (1.11.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (10.0.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (2023.12.9)
# Requirement already satisfied: packaging>=21 in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (23.1)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\azkai\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (0.3)

# %%
from skimage.metrics import structural_similarity as ssim
import cv2

original_image1 =cv2.imread(r'D:\afifa (badin)\HH-ALPSRP187250480-H2.2_UA.tif', 0)  
denoised_image1 = cv2.GaussianBlur(original_image1, (5, 5), 0)
ssim_value1 = ssim(original_image1, denoised_image1)
print(f"Structural Similarity Index (SSIM) of image 1: {ssim_value1}")

original_image2 =cv2.imread(r'D:\afifa (badin)\HV-ALPSRP187250480-H2.2_UA.tif', 0)  
denoised_image2 = cv2.GaussianBlur(original_image2, (5, 5), 0)
ssim_value2 = ssim(original_image2, denoised_image2)
print(f"Structural Similarity Index (SSIM) of image 2: {ssim_value2}")
# Out:
# Structural Similarity Index (SSIM) of image 1: 0.9243955870153573
# Structural Similarity Index (SSIM) of image 2: 0.9862916095225638

# %% [markdown]
# READING SPECIFIC PIXEL VALUE

# %%
import numpy as np
original_image1 =cv2.imread(r'D:\afifa (badin)\HH-ALPSRP187250480-H2.2_UA.tif', 0)  
denoised_image1 = cv2.GaussianBlur(original_image1, (7, 7), 3)

original_image2 =cv2.imread(r'D:\afifa (badin)\HV-ALPSRP187250480-H2.2_UA.tif', 0)  
denoised_image2 = cv2.GaussianBlur(original_image2, (7, 7), 3)

original_pixels1 = np.array(original_image1)
denoised_pixels1 = np.array(denoised_image1)
original_pixels2 = np.array(original_image2)
denoised_pixels2 = np.array(denoised_image2)

row, col = 150, 150
original_pixel_value1 = original_pixels1[row, col]
denoised_pixel_value1 = denoised_pixels1[row, col]
original_pixel_value2 = original_pixels2[row, col]
denoised_pixel_value2 = denoised_pixels2[row, col]

print(f'Original pixel value at ({row}, {col} for image 1): {original_pixel_value1}')
print(f'Denoised pixel value at ({row}, {col} for image 1): {denoised_pixel_value1}')

print(f'Original pixel value at ({row}, {col} for image 2): {original_pixel_value2}')
print(f'Denoised pixel value at ({row}, {col} for image 2): {denoised_pixel_value2}')
# Out:
# Original pixel value at (150, 150 for image 1): 6
# Denoised pixel value at (150, 150 for image 1): 8
# Original pixel value at (150, 150 for image 2): 2
# Denoised pixel value at (150, 150 for image 2): 3

# %% [markdown]
# FOURIER TRANSFORM

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

original_image =cv2.imread(r'D:\afifa (badin)\HH-ALPSRP187250480-H2.2_UA.tif', 0)  

denoised_image = cv2.imread('denoised_image.tif', 0)

if original_image is not None and denoised_image is not None:
    original_transform = np.fft.fft2(original_image)
    original_transform = np.fft.fftshift(original_transform)
    original_magnitude = np.abs(original_transform)
    original_phase = np.angle(original_transform)

    denoised_transform = np.fft.fft2(denoised_image)
    denoised_transform = np.fft.fftshift(denoised_transform)
    denoised_magnitude = np.abs(denoised_transform)
    denoised_phase = np.angle(denoised_transform)
    
    print("Original Image Amplitude (Magnitude):")
    print(original_magnitude)

    print("Denoised Image Amplitude (Magnitude):")
    print(denoised_magnitude)

    print("Original Image Phase:")
    print(original_phase)

    print("Denoised Image Phase:")
    print(denoised_phase)

    plt.subplot(221), plt.imshow(original_image, cmap='gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])

   
    plt.subplot(222), plt.imshow(np.log(original_magnitude), cmap='gray')
    plt.title('Original Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

    plt.subplot(223), plt.imshow(original_phase, cmap='gray')
    plt.title('Original Phase Spectrum'), plt.xticks([]), plt.yticks([])

    plt.subplot(224), plt.imshow(denoised_image, cmap='gray')
    plt.title('Denoised Image'), plt.xticks([]), plt.yticks([])

    plt.show()

else:
    print("Error: Unable to load image(s). Please check the file paths.")
# Out:
# Original Image Amplitude (Magnitude):
# [[2718.         3511.22951384 1777.30482333 ... 3623.84643218
#   1777.30482333 3511.22951384]
#  [2493.32322382 6425.2512951  2837.68498213 ... 2630.89917064
#   3372.25239601 3553.48128958]
#  [1182.93849323 3615.94741344 1840.95954274 ... 2582.43991985
#   5238.0522293  1196.16211577]
#  ...
#  [2157.92266665 2695.51326924 3648.01171611 ... 5458.89638861
#   3087.0300589  4469.96922511]
#  [1182.93849323 1196.16211577 5238.0522293  ... 2905.7626274
#   1840.95954274 3615.94741344]
#  [2493.32322382 3553.48128958 3372.25239601 ... 1325.82183906
#   2837.68498213 6425.2512951 ]]
# Denoised Image Amplitude (Magnitude):
# [[ 257.         2182.80744833 2455.62399574 ... 1024.14588121
#   2455.62399574 2182.80744833]
#  [ 742.76229625 1983.11311917  699.76074472 ...  245.62589174
#    902.05693009 1593.78771606]
#  [1963.84098742 1683.62221518  707.21920281 ... 1211.27388637
#   2698.4907046  1789.20972785]
#  ...
#  [ 989.49346886 2944.38314517  897.59238052 ... 1272.55238739
#    836.45300764  567.04574759]
#  [1963.84098742 1789.20972785 2698.4907046  ...  954.90872107
#    707.21920281 1683.62221518]
#  [ 742.76229625 1593.78771606  902.05693009 ... 1471.07904519
#    699.76074472 1983.11311917]]
# Original Image Phase:
# [[-1.40644589e-15 -6.10587619e-01 -1.35503724e+00 ... -5.05696006e-02
#    1.35503724e+00  6.10587619e-01]
#  [-1.94831722e+00  1.48413829e+00 -2.56458569e+00 ... -1.01172862e+00
#    2.35519901e+00 -9.26597677e-01]
#  [-3.04762102e+00  4.19212217e-02 -4.69835746e-01 ... -1.50891976e+00
#    2.03836642e+00 -2.85058380e+00]
#  ...
#  [-1.17582608e+00  1.49935150e+00 -1.42279784e+00 ...  9.20816617e-01
#    3.04726510e+00 -2.04568565e+00]
#  [ 3.04762102e+00  2.85058380e+00 -2.03836642e+00 ... -3.82898818e-01
#    4.69835746e-01 -4.19212217e-02]
#  [ 1.94831722e+00  9.26597677e-01 -2.35519901e+00 ...  1.92853977e+00
#    2.56458569e+00 -1.48413829e+00]]
# Denoised Image Phase:
# [[ 1.99062556e-14 -1.77358861e+00  4.36649444e-01 ... -1.55335901e-01
#   -4.36649444e-01  1.77358861e+00]
#  [ 2.35897322e+00  2.09641787e+00  2.40634044e+00 ... -1.40744192e+00
#   -1.23646735e+00 -2.83478542e+00]
#  [-1.24560016e+00  2.28889754e+00 -2.05428187e+00 ...  8.79630503e-01
#   -2.58117828e+00  1.31034448e+00]
#  ...
#  [-2.27006484e+00 -1.49883976e+00 -1.56372688e+00 ...  1.45683899e+00
#    2.81575364e+00 -1.47392437e+00]
#  [ 1.24560016e+00 -1.31034448e+00  2.58117828e+00 ... -1.44818716e+00
#    2.05428187e+00 -2.28889754e+00]
#  [-2.35897322e+00  2.83478542e+00  1.23646735e+00 ...  7.47884782e-01
#   -2.40634044e+00 -2.09641787e+00]]
